# %% [markdown]
# # Import dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="d0TYZxZJCWWTuBFwxYNI")
project = rf.workspace("bangkit-academy-rnfpg").project("acne-detection-g5vvz")
version = project.version(1)
dataset = version.download("folder")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
print(dataset.location)
# Out:
# c:\Users\yosua\Downloads\klasifikasi-jerawat\Acne-detection-1

# %% [markdown]
# # Keluarkan kelas dari train-valid-test

# %%
import os
import shutil

# Deteksi lokasi folder dataset Roboflow secara dinamis
dataset_path = os.path.abspath("Acne-detection-1")
parent_dir = os.path.dirname(dataset_path)

# Buat folder baru untuk penggabungan di luar folder dataset
merged_path = os.path.join(parent_dir, "merged_acne_dataset")
os.makedirs(merged_path, exist_ok=True)

# Folder yang akan digabungkan (train, valid, test)
splits = ['train', 'valid', 'test']

for split in splits:
    split_path = os.path.join(dataset_path, split)
    if not os.path.exists(split_path):
        continue

    # Iterasi semua folder kelas di dalam split
    for class_name in os.listdir(split_path):
        class_dir = os.path.join(split_path, class_name)
        if not os.path.isdir(class_dir):
            continue

        # Buat folder kelas di folder penggabungan jika belum ada
        merged_class_dir = os.path.join(merged_path, class_name)
        os.makedirs(merged_class_dir, exist_ok=True)

        # Salin semua gambar dari folder split ke folder gabungan
        for img_file in os.listdir(class_dir):
            src_file = os.path.join(class_dir, img_file)
            dst_file = os.path.join(merged_class_dir, img_file)

            # Hindari overwrite dengan penamaan unik
            if os.path.exists(dst_file):
                base, ext = os.path.splitext(img_file)
                counter = 1
                while True:
                    new_name = f"{base}_{counter}{ext}"
                    dst_file = os.path.join(merged_class_dir, new_name)
                    if not os.path.exists(dst_file):
                        break
                    counter += 1

            shutil.copy2(src_file, dst_file)

print(f"Dataset telah digabungkan ke dalam: {merged_path}")
# Out:
# Dataset telah digabungkan ke dalam: c:\Users\yosua\Downloads\klasifikasi-jerawat\merged_acne_dataset

# %% [markdown]
# # hapus folder deteksi Acne karena akan melakukan klasifikasi

# %%
acne_folder = os.path.join(merged_path, "Acne")

if os.path.isdir(acne_folder):
    shutil.rmtree(acne_folder)
    print("Folder 'Acne' telah dihapus")
else:
    print("Folder 'Acne' tidak ditemukan. Tidak ada yang perlu dihapus.")
# Out:
# Folder 'Acne' telah dihapus

# %% [markdown]
# # Menggabungkan kelas yang mirip menjadi kelas utama

# %%
import os
import shutil

# Pastikan ini adalah path hasil penggabungan sebelumnya
merged_path = os.path.join(parent_dir, "merged_acne_dataset")

# Iterasi semua folder dalam folder gabungan
for folder_name in os.listdir(merged_path):
    folder_path = os.path.join(merged_path, folder_name)

    # Periksa apakah ini folder dan diawali dengan 'Acne '
    if os.path.isdir(folder_path) and folder_name.startswith("Acne "):
        # Ambil nama target setelah "Acne "
        target_name = folder_name.replace("Acne ", "", 1).strip()
        target_path = os.path.join(merged_path, target_name)

        # Buat folder target jika belum ada
        os.makedirs(target_path, exist_ok=True)

        # Pindahkan semua file dari folder asal ke folder target
        for file_name in os.listdir(folder_path):
            src_file = os.path.join(folder_path, file_name)
            dst_file = os.path.join(target_path, file_name)

            # Hindari overwrite
            if os.path.exists(dst_file):
                base, ext = os.path.splitext(file_name)
                counter = 1
                while True:
                    new_name = f"{base}_{counter}{ext}"
                    dst_file = os.path.join(target_path, new_name)
                    if not os.path.exists(dst_file):
                        break
                    counter += 1

            shutil.move(src_file, dst_file)

        # Setelah semua dipindahkan, hapus folder lama
        shutil.rmtree(folder_path)
        print(f"Folder '{folder_name}' telah digabung ke '{target_name}' dan dihapus.")

print("Penyatuan klasifikasi jerawat berhasil dilakukan,.")
# Out:
# Folder 'Acne Blackhead' telah digabung ke 'Blackhead' dan dihapus.
# Folder 'Acne Blackhead Crystanlline' telah digabung ke 'Blackhead Crystanlline' dan dihapus.
# Folder 'Acne Blackhead Crystanlline Papular' telah digabung ke 'Blackhead Crystanlline Papular' dan dihapus.
# Folder 'Acne Blackhead Crystanlline Purulent' telah digabung ke 'Blackhead Crystanlline Purulent' dan dihapus.
# Folder 'Acne Blackhead Cystic' telah digabung ke 'Blackhead Cystic' dan dihapus.
# Folder 'Acne Blackhead Cystic Folliculitis' telah digabung ke 'Blackhead Cystic Folliculitis' dan dihapus.
# Folder 'Acne Blackhead Cystic Folliculitis Keloid Papular' telah digabung ke 'Blackhead Cystic Folliculitis Keloid Papular' dan dihapus.
# Folder 'Acne Blackhead Cystic Folliculitis Milium Papular Purulent' telah digabung ke 'Blackhead Cystic Folliculitis Milium Papular Purulent' dan dihapus.
# Folder 'Acne Blackhead Cystic Folliculitis Papular Purulent' telah digabung ke 'Blackhead Cystic Folliculitis Papular Purulent' dan dihapus.
# Folder 'Acne Blackhead Cystic Keloid Milium Papular' telah digabung ke 'Blackhead Cystic Keloid Milium Papular' dan dihapus.
# Folder 'Acne Blackhead Cystic Keloid Milium Papular Purulent' telah digabung ke 'Blackhead Cystic Keloid Milium Papular Purulent' dan dihapus.
# Folder 'Acne Blackhead Cystic Keloid Papular Purulent' telah digabung ke 'Blackhead Cystic Keloid Papular Purulent' dan dihapus.
# Folder 'Acne Blackhead Cystic Keloid Purulent' telah digabung ke 'Blackhead Cystic Keloid Purulent' dan dihapus.
# Folder 'Acne Blackhead Cystic Milium' telah digabung ke 'Blackhead Cystic Milium' dan dihapus.
# Folder 'Acne Blackhead Cystic Milium Papular' telah digabung ke 'Blackhead Cystic Milium Papular' dan dihapus.
# Folder 'Acne Blackhead Cystic Milium Papular Purulent' telah digabung ke 'Blackhead Cystic Milium Papular Purulent' dan dihapus.
# Folder 'Acne Blackhead Cystic Milium Purulent' telah digabung ke 'Blackhead Cystic Milium Purulent' dan dihapus.
# Folder 'Acne Blackhead Cystic Papular' telah digabung ke 'Blackhead Cystic Papular' dan dihapus.
# Folder 'Acne Blackhead Cystic Papular Purulent' telah digabung ke 'Blackhead Cystic Papular Purulent' dan dihapus.
# Folder 'Acne Blackhead Cystic Purulent' telah digabung ke 'Blackhead Cystic Purulent' dan dihapus.
# Folder 'Acne Blackhead Folliculitis Keloid' telah digabung ke 'Blackhead Folliculitis Keloid' dan dihapus.
# Folder 'Acne Blackhead Folliculitis Keloid Milium Papular Purulent' telah digabung ke 'Blackhead Folliculitis Keloid Milium Papular Purulent' dan dihapus.
# Folder 'Acne Blackhead Folliculitis Keloid Milium Purulent' telah digabung ke 'Blackhead Folliculitis Keloid Milium Purulent' dan dihapus.
# Folder 'Acne Blackhead Folliculitis Keloid Papular Purulent' telah digabung ke 'Blackhead Folliculitis Keloid Papular Purulent' dan dihapus.
# Folder 'Acne Blackhead Folliculitis Milium' telah digabung ke 'Blackhead Folliculitis Milium' dan dihapus.
# Folder 'Acne Blackhead Folliculitis Milium Papular' telah digabung ke 'Blackhead Folliculitis Milium Papular' dan dihapus.
# Folder 'Acne Blackhead Folliculitis Milium Papular Purulent' telah digabung ke 'Blackhead Folliculitis Milium Papular Purulent' dan dihapus.
# Folder 'Acne Blackhead Folliculitis Papular' telah digabung ke 'Blackhead Folliculitis Papular' dan dihapus.
# Folder 'Acne Blackhead Folliculitis Papular Purulent' telah digabung ke 'Blackhead Folliculitis Papular Purulent' dan dihapus.
# Folder 'Acne Blackhead Folliculitis Purulent' telah digabung ke 'Blackhead Folliculitis Purulent' dan dihapus.
# Folder 'Acne Blackhead Keloid' telah digabung ke 'Blackhead Keloid' dan dihapus.
# Folder 'Acne Blackhead Keloid Milium' telah digabung ke 'Blackhead Keloid Milium' dan dihapus.
# Folder 'Acne Blackhead Keloid Milium Papular' telah digabung ke 'Blackhead Keloid Milium Papular' dan dihapus.
# Folder 'Acne Blackhead Keloid Milium Purulent' telah digabung ke 'Blackhead Keloid Milium Purulent' dan dihapus.
# Folder 'Acne Blackhead Keloid Papular' telah digabung ke 'Blackhead Keloid Papular' dan dihapus.
# Folder 'Acne Blackhead Keloid Papular Purulent' telah digabung ke 'Blackhead Keloid Papular Purulent' dan dihapus.
# Folder 'Acne Blackhead Keloid Purulent' telah digabung ke 'Blackhead Keloid Purulent' dan dihapus.
# Folder 'Acne Blackhead Milium' telah digabung ke 'Blackhead Milium' dan dihapus.
# Folder 'Acne Blackhead Milium Papular' telah digabung ke 'Blackhead Milium Papular' dan dihapus.
# Folder 'Acne Blackhead Milium Papular Purulent' telah digabung ke 'Blackhead Milium Papular Purulent' dan dihapus.
# Folder 'Acne Blackhead Milium Purulent' telah digabung ke 'Blackhead Milium Purulent' dan dihapus.
# Folder 'Acne Blackhead Papular' telah digabung ke 'Blackhead Papular' dan dihapus.
# Folder 'Acne Blackhead Papular Purulent' telah digabung ke 'Blackhead Papular Purulent' dan dihapus.
# Folder 'Acne Blackhead Purulent' telah digabung ke 'Blackhead Purulent' dan dihapus.
# Folder 'Acne Conglobata Papular Purulent' telah digabung ke 'Conglobata Papular Purulent' dan dihapus.
# Folder 'Acne Conglobata Purulent' telah digabung ke 'Conglobata Purulent' dan dihapus.
# Folder 'Acne Crystanlline Cystic' telah digabung ke 'Crystanlline Cystic' dan dihapus.
# Folder 'Acne Crystanlline Cystic Purulent' telah digabung ke 'Crystanlline Cystic Purulent' dan dihapus.
# Folder 'Acne Crystanlline Folliculitis Purulent' telah digabung ke 'Crystanlline Folliculitis Purulent' dan dihapus.
# Folder 'Acne Crystanlline Keloid Papular Purulent' telah digabung ke 'Crystanlline Keloid Papular Purulent' dan dihapus.
# Folder 'Acne Crystanlline Keloid Purulent' telah digabung ke 'Crystanlline Keloid Purulent' dan dihapus.
# Folder 'Acne Crystanlline Milium' telah digabung ke 'Crystanlline Milium' dan dihapus.
# Folder 'Acne Crystanlline Papular Purulent' telah digabung ke 'Crystanlline Papular Purulent' dan dihapus.
# Folder 'Acne Crystanlline Purulent' telah digabung ke 'Crystanlline Purulent' dan dihapus.
# Folder 'Acne Cystic' telah digabung ke 'Cystic' dan dihapus.
# Folder 'Acne Cystic Folliculitis Milium Papular Purulent' telah digabung ke 'Cystic Folliculitis Milium Papular Purulent' dan dihapus.
# Folder 'Acne Cystic Folliculitis Papular' telah digabung ke 'Cystic Folliculitis Papular' dan dihapus.
# Folder 'Acne Cystic Folliculitis Papular Purulent' telah digabung ke 'Cystic Folliculitis Papular Purulent' dan dihapus.
# Folder 'Acne Cystic Keloid' telah digabung ke 'Cystic Keloid' dan dihapus.
# Folder 'Acne Cystic Keloid Milium Papular' telah digabung ke 'Cystic Keloid Milium Papular' dan dihapus.
# Folder 'Acne Cystic Keloid Milium Papular Purulent' telah digabung ke 'Cystic Keloid Milium Papular Purulent' dan dihapus.
# Folder 'Acne Cystic Keloid Milium Purulent' telah digabung ke 'Cystic Keloid Milium Purulent' dan dihapus.
# Folder 'Acne Cystic Keloid Papular' telah digabung ke 'Cystic Keloid Papular' dan dihapus.
# Folder 'Acne Cystic Keloid Papular Purulent' telah digabung ke 'Cystic Keloid Papular Purulent' dan dihapus.
# Folder 'Acne Cystic Keloid Purulent' telah digabung ke 'Cystic Keloid Purulent' dan dihapus.
# Folder 'Acne Cystic Milium Papular' telah digabung ke 'Cystic Milium Papular' dan dihapus.
# Folder 'Acne Cystic Milium Papular Purulent' telah digabung ke 'Cystic Milium Papular Purulent' dan dihapus.
# Folder 'Acne Cystic Milium Purulent' telah digabung ke 'Cystic Milium Purulent' dan dihapus.
# Folder 'Acne Cystic Papular' telah digabung ke 'Cystic Papular' dan dihapus.
# Folder 'Acne Cystic Papular Purulent' telah digabung ke 'Cystic Papular Purulent' dan dihapus.
# Folder 'Acne Cystic Purulent' telah digabung ke 'Cystic Purulent' dan dihapus.
# Folder 'Acne Folliculitis' telah digabung ke 'Folliculitis' dan dihapus.
# Folder 'Acne Folliculitis Keloid Milium' telah digabung ke 'Folliculitis Keloid Milium' dan dihapus.
# Folder 'Acne Folliculitis Keloid Papular Purulent' telah digabung ke 'Folliculitis Keloid Papular Purulent' dan dihapus.
# Folder 'Acne Folliculitis Papular' telah digabung ke 'Folliculitis Papular' dan dihapus.
# Folder 'Acne Folliculitis Papular Purulent' telah digabung ke 'Folliculitis Papular Purulent' dan dihapus.
# Folder 'Acne Folliculitis Purulent' telah digabung ke 'Folliculitis Purulent' dan dihapus.
# Folder 'Acne Keloid' telah digabung ke 'Keloid' dan dihapus.
# Folder 'Acne Keloid Milium' telah digabung ke 'Keloid Milium' dan dihapus.
# Folder 'Acne Keloid Milium Papular' telah digabung ke 'Keloid Milium Papular' dan dihapus.
# Folder 'Acne Keloid Milium Papular Purulent' telah digabung ke 'Keloid Milium Papular Purulent' dan dihapus.
# Folder 'Acne Keloid Milium Purulent' telah digabung ke 'Keloid Milium Purulent' dan dihapus.
# Folder 'Acne Keloid Papular' telah digabung ke 'Keloid Papular' dan dihapus.
# Folder 'Acne Keloid Papular Purulent' telah digabung ke 'Keloid Papular Purulent' dan dihapus.
# Folder 'Acne Keloid Purulent' telah digabung ke 'Keloid Purulent' dan dihapus.
# Folder 'Acne Milium' telah digabung ke 'Milium' dan dihapus.
# Folder 'Acne Milium Papular' telah digabung ke 'Milium Papular' dan dihapus.
# Folder 'Acne Milium Papular Purulent' telah digabung ke 'Milium Papular Purulent' dan dihapus.
# Folder 'Acne Milium Purulent' telah digabung ke 'Milium Purulent' dan dihapus.
# Folder 'Acne Papular' telah digabung ke 'Papular' dan dihapus.
# Folder 'Acne Papular Purulent' telah digabung ke 'Papular Purulent' dan dihapus.
# Folder 'Acne Purulent' telah digabung ke 'Purulent' dan dihapus.
# Penyatuan klasifikasi jerawat berhasil dilakukan,.

# %%
import os
import shutil
from collections import defaultdict

# Path dataset hasil merge
merged_path = os.path.join(parent_dir, "merged_acne_dataset")

# Mapping kata pertama ke folder-folder dengan awalan sama
prefix_map = defaultdict(list)

# Identifikasi semua folder
for folder_name in os.listdir(merged_path):
    folder_path = os.path.join(merged_path, folder_name)
    if os.path.isdir(folder_path):
        # Ambil kata pertama
        prefix = folder_name.split()[0]
        prefix_map[prefix].append(folder_name)

# Proses penggabungan folder berdasarkan prefix
for prefix, folders in prefix_map.items():
    if len(folders) <= 1:
        continue  # Tidak perlu digabung kalau hanya satu

    target_folder = os.path.join(merged_path, prefix)
    os.makedirs(target_folder, exist_ok=True)

    for folder_name in folders:
        current_folder = os.path.join(merged_path, folder_name)
        if current_folder == target_folder:
            continue  # Lewati jika sudah merupakan target

        # Pindahkan semua file
        for file_name in os.listdir(current_folder):
            src_file = os.path.join(current_folder, file_name)
            dst_file = os.path.join(target_folder, file_name)

            # Hindari overwrite
            if os.path.exists(dst_file):
                base, ext = os.path.splitext(file_name)
                counter = 1
                while True:
                    new_name = f"{base}_{counter}{ext}"
                    dst_file = os.path.join(target_folder, new_name)
                    if not os.path.exists(dst_file):
                        break
                    counter += 1

            shutil.move(src_file, dst_file)

        # Hapus folder lama setelah kosong
        shutil.rmtree(current_folder)
        print(f"Folder '{folder_name}' digabung ke '{prefix}' dan dihapus.")
# Out:
# Folder 'Blackhead Crystanlline' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Crystanlline Cystic' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Crystanlline Cystic Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Crystanlline Folliculitis Papular Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Crystanlline Papular' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Crystanlline Papular Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Crystanlline Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Keloid Papular Purulent Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Keloid Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Keloid Papular Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Keloid Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Milium Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Milium Papular Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Papular' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Papular Purulent Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Papular Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Papular Scars' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Papular Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Papular Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Papular Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Papular Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Flat_wart Scars' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Folliculitis' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Folliculitis Keloid Papular' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Folliculitis Keloid Papular Purulent Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Folliculitis Milium Papular Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Folliculitis Milium Papular Purulent Scars' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Folliculitis Milium Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Folliculitis Papular Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Folliculitis Papular Purulent Scars' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Folliculitis Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Folliculitis Papular Purulent Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Folliculitis Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Folliculitis Papular Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Folliculitis Papular Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Folliculitis Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Keloid Milium Papular' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Keloid Milium Papular Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Keloid Milium Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Keloid Papular Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Keloid Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Keloid Papular Purulent Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Keloid Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Keloid Papular Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Keloid Papular Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Keloid Papular Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Keloid Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium Papular' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium Papular Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium Papular Purulent Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium Papular Purulent Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium Papular Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium Papular Scars' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium Papular Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium Papular Sebo-crystan-conglo Syringoma' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium Papular Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium Papular Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium Purulent Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium Scars' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Milium Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Papular' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Papular Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Papular Purulent Scars' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Papular Purulent Scars Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Papular Purulent Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Papular Purulent Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Papular Purulent Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Papular Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Papular Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Papular Scars Syringoma' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Papular Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Papular Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Papular Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Purulent Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Purulent Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Purulent Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Purulent Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Cystic Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Folliculitis Milium Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Folliculitis Milium Sebo-crystan-conglo Syringoma' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Folliculitis Papular' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Folliculitis Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Folliculitis Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Folliculitis Papular Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Folliculitis Papular Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Keloid' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Keloid Milium Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Keloid Milium Papular Purulent Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Keloid Papular' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Keloid Papular Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Keloid Papular Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Keloid Purulent Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Keloid Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Keloid Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Milium' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Milium Papular Purulent Scars Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Milium Papular Purulent Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Milium Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Milium Papular Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Milium Papular Scars Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Milium Purulent Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Milium Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Papular' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Papular Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Papular Purulent Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Papular Purulent Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Papular Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Papular Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Papular Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Papular Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Papular Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Purulent Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Purulent Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Purulent Sebo-crystan-conglo Syringoma' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Sebo-crystan-conglo Syringoma' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Flat_wart Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Keloid' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Keloid Milium Papular Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Keloid Milium Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Keloid Milium Papular Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Keloid Milium Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Keloid Milium Syringoma' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Keloid Papular Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Keloid Papular Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Keloid Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Milium' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Milium Papular' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Milium Papular Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Milium Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Milium Papular Purulent Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Milium Papular Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Milium Syringoma' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Milium Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Papular' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Papular Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Papular Purulent Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Papular Purulent Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Papular Purulent Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Papular Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Papular Scars' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Papular Sebo-crystan-conglo Syringoma' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Papular Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Papular Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Papular Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Purulent Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Folliculitis Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Milium' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Milium Papular' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Milium Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Milium Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Milium Purulent Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Milium Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Milium Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Papular' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Papular Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Papular Purulent Scars Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Papular Purulent Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Papular Purulent Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Papular Purulent Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Papular Purulent Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Papular Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Papular Scars' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Papular Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Papular Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Papular Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Papular Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Papular Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Purulent Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Keloid Scars Syringoma' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Papular' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Papular Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Papular Purulent Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Papular Purulent Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Papular Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Papular Scars' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Papular Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Papular Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Papular Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Papular Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Papular Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Purulent Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Purulent Scars Sebo-crystan-conglo Syringoma' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Purulent Scars Syringoma' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Purulent Syringoma' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Scars' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Syringoma' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Milium Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Purulent Scars Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Purulent Scars Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Purulent Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Purulent Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Purulent Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Scars' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Scars Sebo-crystan-conglo Syringoma' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Scars Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Scars Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Sebo-crystan-conglo Syringoma' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Papular Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Purulent' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Purulent Scars Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Purulent Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Purulent Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Scars' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Scars Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Scars Sebo-crystan-conglo Syringoma' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Scars Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Sebo-crystan-conglo' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Sebo-crystan-conglo Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Syringoma' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Syringoma Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Blackhead Whitehead' digabung ke 'Blackhead' dan dihapus.
# Folder 'Conglobata Crystanlline Cystic Papular Purulent' digabung ke 'Conglobata' dan dihapus.
# Folder 'Conglobata Crystanlline Papular' digabung ke 'Conglobata' dan dihapus.
# Folder 'Conglobata Crystanlline Purulent' digabung ke 'Conglobata' dan dihapus.
# Folder 'Conglobata Cystic Purulent' digabung ke 'Conglobata' dan dihapus.
# Folder 'Conglobata Papular' digabung ke 'Conglobata' dan dihapus.
# Folder 'Conglobata Papular Purulent' digabung ke 'Conglobata' dan dihapus.
# Folder 'Conglobata Purulent' digabung ke 'Conglobata' dan dihapus.
# Folder 'Crystanlline Cystic' digabung ke 'Crystanlline' dan dihapus.
# Folder 'Crystanlline Cystic Papular' digabung ke 'Crystanlline' dan dihapus.
# Folder 'Crystanlline Cystic Papular Purulent' digabung ke 'Crystanlline' dan dihapus.
# Folder 'Crystanlline Cystic Purulent' digabung ke 'Crystanlline' dan dihapus.
# Folder 'Crystanlline Folliculitis' digabung ke 'Crystanlline' dan dihapus.
# Folder 'Crystanlline Folliculitis Papular Purulent' digabung ke 'Crystanlline' dan dihapus.
# Folder 'Crystanlline Folliculitis Purulent' digabung ke 'Crystanlline' dan dihapus.
# Folder 'Crystanlline Keloid' digabung ke 'Crystanlline' dan dihapus.
# Folder 'Crystanlline Keloid Papular Purulent' digabung ke 'Crystanlline' dan dihapus.
# Folder 'Crystanlline Keloid Purulent' digabung ke 'Crystanlline' dan dihapus.
# Folder 'Crystanlline Milium' digabung ke 'Crystanlline' dan dihapus.
# Folder 'Crystanlline Papular' digabung ke 'Crystanlline' dan dihapus.
# Folder 'Crystanlline Papular Purulent' digabung ke 'Crystanlline' dan dihapus.
# Folder 'Crystanlline Purulent' digabung ke 'Crystanlline' dan dihapus.
# Folder 'Cystic Flat_wart' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Folliculitis Keloid Milium' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Folliculitis Papular' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Folliculitis Papular Purulent Scars Sebo-crystan-conglo Syringoma' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Folliculitis Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Keloid Milium Papular Purulent' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Keloid Milium Purulent' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Keloid Papular Purulent Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Keloid Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Milium Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Milium Papular Purulent Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Milium Papular Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Milium Papular Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Milium Purulent Scars Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Papular' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Papular Purulent' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Papular Purulent Scars Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Papular Purulent Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Papular Purulent Syringoma' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Papular Scars' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Papular Scars Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Papular Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Papular Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Flat_wart Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Keloid' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Keloid Papular Purulent Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Keloid Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Keloid Papular Scars Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Keloid Papular Scars Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Keloid Papular Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Keloid Papular Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Keloid Papular Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Milium Papular' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Milium Papular Purulent' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Milium Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Papular' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Papular Purulent' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Papular Purulent Scars Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Papular Purulent Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Papular Purulent Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Papular Scars Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Papular Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Purulent Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Folliculitis Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Milium Papular' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Milium Papular Purulent' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Milium Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Milium Purulent' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Papular' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Papular Purulent' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Papular Purulent Scars Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Papular Purulent Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Papular Purulent Syringoma' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Papular Purulent Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Papular Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Papular Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Purulent' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Purulent Scars Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Purulent Scars Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Keloid Purulent Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Milium Papular' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Milium Papular Purulent' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Milium Papular Purulent Scars Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Milium Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Milium Papular Purulent Scars Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Milium Papular Purulent Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Milium Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Milium Papular Purulent Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Milium Papular Scars Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Milium Papular Sebo-crystan-conglo Syringoma' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Milium Papular Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Milium Papular Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Milium Purulent' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Milium Purulent Scars Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Milium Purulent Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Milium Purulent Syringoma' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Purulent' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Purulent Scars' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Purulent Scars Sebo-crystan-conglo Syringoma' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Purulent Scars Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Purulent Scars Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Purulent Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Purulent Sebo-crystan-conglo Syringoma' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Purulent Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Purulent Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Scars Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Scars Syringoma Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Scars Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Syringoma' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Papular Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Purulent' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Purulent Scars Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Purulent Scars Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Purulent Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Scars' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Sebo-crystan-conglo' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Syringoma Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Cystic Whitehead' digabung ke 'Cystic' dan dihapus.
# Folder 'Flat_wart Folliculitis Keloid' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Folliculitis Keloid Papular Syringoma' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Folliculitis Keloid Purulent' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Folliculitis Milium Papular' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Folliculitis Milium Papular Purulent' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Folliculitis Milium Papular Scars Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Folliculitis Milium Scars Syringoma' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Folliculitis Milium Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Folliculitis Papular' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Folliculitis Papular Purulent' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Folliculitis Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Folliculitis Papular Purulent Syringoma' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Folliculitis Papular Purulent Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Folliculitis Papular Scars Sebo-crystan-conglo' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Folliculitis Papular Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Folliculitis Purulent Sebo-crystan-conglo' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Keloid' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Keloid Milium Purulent Scars Sebo-crystan-conglo' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Keloid Milium Purulent Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Keloid Milium Scars' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Keloid Milium Scars Syringoma' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Keloid Papular Purulent' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Keloid Papular Purulent Scars' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Keloid Papular Purulent Scars Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Keloid Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Keloid Papular Purulent Scars Syringoma' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Keloid Papular Purulent Sebo-crystan-conglo' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Keloid Papular Scars Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Keloid Papular Sebo-crystan-conglo' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Keloid Papular Sebo-crystan-conglo Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Keloid Papular Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Keloid Scars Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Keloid Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Papular Purulent Sebo-crystan-conglo' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Papular Purulent Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Papular Purulent Syringoma' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Papular Purulent Syringoma Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Papular Purulent Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Papular Scars Sebo-crystan-conglo Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Papular Scars Syringoma' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Papular Sebo-crystan-conglo' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Papular Syringoma Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Papular Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Purulent Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Purulent Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Scars' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Sebo-crystan-conglo Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Syringoma' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Milium Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Papular' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Papular Purulent' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Papular Purulent Scars Sebo-crystan-conglo Syringoma' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Papular Purulent Scars Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Papular Purulent Scars Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Papular Purulent Sebo-crystan-conglo' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Papular Purulent Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Papular Scars Sebo-crystan-conglo Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Papular Scars Syringoma Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Papular Scars Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Papular Sebo-crystan-conglo Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Papular Syringoma' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Papular Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Purulent Scars Syringoma Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Purulent Scars Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Purulent Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Scars' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Flat_wart Whitehead' digabung ke 'Flat_wart' dan dihapus.
# Folder 'Folliculitis Keloid' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Keloid Milium' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Keloid Milium Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Keloid Milium Papular Syringoma Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Keloid Papular' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Keloid Papular Purulent' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Keloid Papular Purulent Sebo-crystan-conglo' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Keloid Papular Sebo-crystan-conglo' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Keloid Papular Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Keloid Purulent Sebo-crystan-conglo' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Keloid Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Keloid Sebo-crystan-conglo' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Milium Papular Purulent' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Milium Papular Purulent Sebo-crystan-conglo' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Milium Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Milium Papular Purulent Syringoma' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Milium Papular Scars' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Milium Papular Scars Syringoma Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Milium Papular Scars Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Milium Papular Sebo-crystan-conglo Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Milium Papular Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Milium Purulent Sebo-crystan-conglo' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Milium Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular Purulent' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular Purulent Scars Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular Purulent Sebo-crystan-conglo' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular Purulent Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular Purulent Syringoma' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular Purulent Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular Scars' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular Scars Sebo-crystan-conglo' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular Scars Sebo-crystan-conglo Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular Scars Syringoma' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular Scars Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular Sebo-crystan-conglo' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular Syringoma Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Papular Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Purulent' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Purulent Scars Sebo-crystan-conglo' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Purulent Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Folliculitis Whitehead' digabung ke 'Folliculitis' dan dihapus.
# Folder 'Keloid Milium' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Milium Papular' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Milium Papular Purulent' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Milium Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Milium Papular Purulent Scars Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Milium Papular Purulent Sebo-crystan-conglo' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Milium Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Milium Papular Scars Sebo-crystan-conglo Syringoma' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Milium Papular Scars Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Milium Purulent' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Milium Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Milium Scars' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Milium Scars Sebo-crystan-conglo Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Papular' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Papular Purulent' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Papular Purulent Scars Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Papular Purulent Scars Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Papular Purulent Sebo-crystan-conglo' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Papular Purulent Syringoma Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Papular Purulent Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Papular Scars Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Papular Sebo-crystan-conglo' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Papular Sebo-crystan-conglo Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Papular Syringoma' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Papular Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Purulent' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Purulent Sebo-crystan-conglo' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Purulent Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Scars Sebo-crystan-conglo Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Sebo-crystan-conglo' digabung ke 'Keloid' dan dihapus.
# Folder 'Keloid Whitehead' digabung ke 'Keloid' dan dihapus.
# Folder 'Milium Papular' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Purulent' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Purulent Scars' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Purulent Scars Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Purulent Scars Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Purulent Sebo-crystan-conglo' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Purulent Sebo-crystan-conglo Syringoma' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Purulent Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Purulent Syringoma' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Purulent Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Scars Sebo-crystan-conglo' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Scars Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Scars Sebo-crystan-conglo Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Scars Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Sebo-crystan-conglo Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Syringoma' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Syringoma Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Papular Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Purulent' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Purulent Scars Sebo-crystan-conglo Syringoma' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Purulent Sebo-crystan-conglo' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Purulent Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Scars Sebo-crystan-conglo Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Scars Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Sebo-crystan-conglo Whitehead' digabung ke 'Milium' dan dihapus.
# Folder 'Milium Syringoma' digabung ke 'Milium' dan dihapus.
# Folder 'Papular Purulent' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Purulent Scars' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Purulent Scars Sebo-crystan-conglo' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Purulent Scars Sebo-crystan-conglo Syringoma' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Purulent Scars Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Purulent Scars Syringoma' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Purulent Scars Whitehead' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Purulent Sebo-crystan-conglo' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Purulent Sebo-crystan-conglo Syringoma' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Purulent Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Purulent Whitehead' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Scars' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Scars Sebo-crystan-conglo' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Scars Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Scars Sebo-crystan-conglo Whitehead' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Scars Syringoma' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Scars Syringoma Whitehead' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Scars Whitehead' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Sebo-crystan-conglo' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Sebo-crystan-conglo Whitehead' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Syringoma' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Syringoma Whitehead' digabung ke 'Papular' dan dihapus.
# Folder 'Papular Whitehead' digabung ke 'Papular' dan dihapus.
# Folder 'Purulent Scars Sebo-crystan-conglo Whitehead' digabung ke 'Purulent' dan dihapus.
# Folder 'Purulent Sebo-crystan-conglo' digabung ke 'Purulent' dan dihapus.
# Folder 'Purulent Sebo-crystan-conglo Whitehead' digabung ke 'Purulent' dan dihapus.
# Folder 'Purulent Whitehead' digabung ke 'Purulent' dan dihapus.
# Folder 'Scars Whitehead' digabung ke 'Scars' dan dihapus.
# Folder 'Sebo-crystan-conglo Syringoma Whitehead' digabung ke 'Sebo-crystan-conglo' dan dihapus.
# Folder 'Sebo-crystan-conglo Whitehead' digabung ke 'Sebo-crystan-conglo' dan dihapus.
# Folder 'Syringoma Whitehead' digabung ke 'Syringoma' dan dihapus.

# %% [markdown]
# # Split dataset

# %%
import os
import shutil
import random

# Path dataset hasil penggabungan
merged_path = os.path.abspath("merged_acne_dataset")
split_base = os.path.join(os.path.dirname(merged_path), "jerawat-split")

# Rasio pembagian
ratios = {
    'train': 0.80,
    'valid': 0.10,
    'test': 0.10
}

# Buat folder target: train, valid, test
for split in ratios:
    for class_name in os.listdir(merged_path):
        class_dir = os.path.join(split_base, split, class_name)
        os.makedirs(class_dir, exist_ok=True)

# Proses pembagian per kelas
for class_name in os.listdir(merged_path):
    class_path = os.path.join(merged_path, class_name)
    if not os.path.isdir(class_path):
        continue

    # Daftar file dalam kelas
    files = os.listdir(class_path)
    random.shuffle(files)

    total = len(files)
    train_end = int(total * ratios['train'])
    valid_end = train_end + int(total * ratios['valid'])

    split_files = {
        'train': files[:train_end],
        'valid': files[train_end:valid_end],
        'test': files[valid_end:]
    }

    # Salin file ke folder baru
    for split, file_list in split_files.items():
        for file_name in file_list:
            src_file = os.path.join(class_path, file_name)
            dst_file = os.path.join(split_base, split, class_name, file_name)
            shutil.copy2(src_file, dst_file)

print(f"Dataset telah terpecah ke dalam folder baru: {split_base}")
# Out:
# Dataset telah terpecah ke dalam folder baru: c:\Users\yosua\Downloads\klasifikasi-jerawat\jerawat-split

# %%
import os

split_base = os.path.abspath("jerawat-split")

train_dir = os.path.join(split_base, "train")
valid_dir = os.path.join(split_base, "valid")
test_dir  = os.path.join(split_base, "test")

print(f"Train directory: {train_dir}")
print(f"Valid directory: {valid_dir}")
print(f"Test directory:  {test_dir}")
# Out:
# Train directory: c:\Users\yosua\Downloads\klasifikasi-jerawat\jerawat-split\train
# Valid directory: c:\Users\yosua\Downloads\klasifikasi-jerawat\jerawat-split\valid
# Test directory:  c:\Users\yosua\Downloads\klasifikasi-jerawat\jerawat-split\test

# %% [markdown]
# # Image Processing

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_width = 128
img_height = 128
image_size = (img_width, img_height)
batch_size = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    shear_range=0.1
)

valid_datagen = ImageDataGenerator(rescale=1./255)
test_datagen  = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(train_dir, target_size=image_size, batch_size=batch_size, class_mode='categorical')
valid_gen = valid_datagen.flow_from_directory(valid_dir, target_size=image_size, batch_size=batch_size, class_mode='categorical')
test_gen  = test_datagen.flow_from_directory(test_dir,  target_size=image_size, batch_size=batch_size, class_mode='categorical', shuffle=False)

num_classes = len(train_gen.class_indices)
print("Kelas ditemukan:", train_gen.class_indices)
print("Jumlah kelas:", num_classes)
# Out:
# Found 46783 images belonging to 14 classes.
# Found 17250 images belonging to 14 classes.
# Found 17417 images belonging to 14 classes.
# Kelas ditemukan: {'Blackhead': 0, 'Conglobata': 1, 'Crystanlline': 2, 'Cystic': 3, 'Flat_wart': 4, 'Folliculitis': 5, 'Keloid': 6, 'Milium': 7, 'Papular': 8, 'Purulent': 9, 'Scars': 10, 'Sebo-crystan-conglo': 11, 'Syringoma': 12, 'Whitehead': 13}
# Jumlah kelas: 14

# %% [markdown]
# # Model

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.regularizers import l2

base_model = MobileNetV2(input_shape=(img_width, img_height, 3), include_top=False, weights='imagenet')
base_model.trainable = False

# for layer in base_model.layers[:100]:
#     layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(x)
x = Dropout(0.5)(x)
output = Dense(num_classes, activation='softmax', kernel_regularizer=l2(0.001))(x)

model = Model(inputs=base_model.input, outputs=output)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# model.summary()

# %% [markdown]
# # Training

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(patience=5, factor=0.3, verbose=1),
    ModelCheckpoint(
        filepath='best_model.keras',  # or 'best_model.h5' for h5 format
        monitor='val_loss',           # or 'val_accuracy' if you prefer
        save_best_only=True,
        save_weights_only=False,
        mode='auto',                  # 'min' for val_loss, 'max' for val_accuracy
        verbose=1
    )
]

history = model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=100,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.8174 - accuracy: 0.4265
# Epoch 1: val_loss improved from inf to 1.63463, saving model to best_model.keras
# 1462/1462 [==============================] - 747s 511ms/step - loss: 1.8174 - accuracy: 0.4265 - val_loss: 1.6346 - val_accuracy: 0.4526 - lr: 0.0010
# Epoch 2/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.7016 - accuracy: 0.4382
# Epoch 2: val_loss improved from 1.63463 to 1.58571, saving model to best_model.keras
# 1462/1462 [==============================] - 601s 411ms/step - loss: 1.7016 - accuracy: 0.4382 - val_loss: 1.5857 - val_accuracy: 0.4614 - lr: 0.0010
# Epoch 3/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6692 - accuracy: 0.4443
# Epoch 3: val_loss improved from 1.58571 to 1.58503, saving model to best_model.keras
# 1462/1462 [==============================] - 565s 387ms/step - loss: 1.6692 - accuracy: 0.4443 - val_loss: 1.5850 - val_accuracy: 0.4397 - lr: 0.0010
# Epoch 4/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6621 - accuracy: 0.4453
# Epoch 4: val_loss improved from 1.58503 to 1.56656, saving model to best_model.keras
# 1462/1462 [==============================] - 569s 389ms/step - loss: 1.6621 - accuracy: 0.4453 - val_loss: 1.5666 - val_accuracy: 0.4665 - lr: 0.0010
# Epoch 5/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6547 - accuracy: 0.4512
# Epoch 5: val_loss did not improve from 1.56656
# 1462/1462 [==============================] - 563s 385ms/step - loss: 1.6547 - accuracy: 0.4512 - val_loss: 1.5750 - val_accuracy: 0.4654 - lr: 0.0010
# Epoch 6/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6516 - accuracy: 0.4533
# Epoch 6: val_loss improved from 1.56656 to 1.53350, saving model to best_model.keras
# 1462/1462 [==============================] - 564s 386ms/step - loss: 1.6516 - accuracy: 0.4533 - val_loss: 1.5335 - val_accuracy: 0.4789 - lr: 0.0010
# Epoch 7/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6416 - accuracy: 0.4540
# Epoch 7: val_loss did not improve from 1.53350
# 1462/1462 [==============================] - 561s 384ms/step - loss: 1.6416 - accuracy: 0.4540 - val_loss: 1.5595 - val_accuracy: 0.4594 - lr: 0.0010
# Epoch 8/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6428 - accuracy: 0.4580
# Epoch 8: val_loss did not improve from 1.53350
# 1462/1462 [==============================] - 566s 387ms/step - loss: 1.6428 - accuracy: 0.4580 - val_loss: 1.5385 - val_accuracy: 0.4758 - lr: 0.0010
# Epoch 9/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6413 - accuracy: 0.4590
# Epoch 9: val_loss did not improve from 1.53350
# 1462/1462 [==============================] - 557s 381ms/step - loss: 1.6413 - accuracy: 0.4590 - val_loss: 1.5435 - val_accuracy: 0.4668 - lr: 0.0010
# Epoch 10/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6360 - accuracy: 0.4585
# Epoch 10: val_loss did not improve from 1.53350
# 1462/1462 [==============================] - 557s 381ms/step - loss: 1.6360 - accuracy: 0.4585 - val_loss: 1.5653 - val_accuracy: 0.4682 - lr: 0.0010
# Epoch 11/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6316 - accuracy: 0.4643
# Epoch 11: val_loss improved from 1.53350 to 1.49386, saving model to best_model.keras
# 1462/1462 [==============================] - 559s 383ms/step - loss: 1.6316 - accuracy: 0.4643 - val_loss: 1.4939 - val_accuracy: 0.4946 - lr: 0.0010
# Epoch 12/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6266 - accuracy: 0.4624
# Epoch 12: val_loss did not improve from 1.49386
# 1462/1462 [==============================] - 559s 382ms/step - loss: 1.6266 - accuracy: 0.4624 - val_loss: 1.5071 - val_accuracy: 0.4894 - lr: 0.0010
# Epoch 13/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6273 - accuracy: 0.4637
# Epoch 13: val_loss did not improve from 1.49386
# 1462/1462 [==============================] - 561s 384ms/step - loss: 1.6273 - accuracy: 0.4637 - val_loss: 1.5337 - val_accuracy: 0.4747 - lr: 0.0010
# Epoch 14/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6325 - accuracy: 0.4640
# Epoch 14: val_loss did not improve from 1.49386
# 1462/1462 [==============================] - 561s 383ms/step - loss: 1.6325 - accuracy: 0.4640 - val_loss: 1.5013 - val_accuracy: 0.4874 - lr: 0.0010
# Epoch 15/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6266 - accuracy: 0.4657
# Epoch 15: val_loss did not improve from 1.49386
# 1462/1462 [==============================] - 561s 384ms/step - loss: 1.6266 - accuracy: 0.4657 - val_loss: 1.5197 - val_accuracy: 0.4860 - lr: 0.0010
# Epoch 16/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6217 - accuracy: 0.4668
# Epoch 16: val_loss improved from 1.49386 to 1.49249, saving model to best_model.keras
# 1462/1462 [==============================] - 560s 383ms/step - loss: 1.6217 - accuracy: 0.4668 - val_loss: 1.4925 - val_accuracy: 0.4900 - lr: 0.0010
# Epoch 17/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6171 - accuracy: 0.4671
# Epoch 17: val_loss did not improve from 1.49249
# 1462/1462 [==============================] - 556s 380ms/step - loss: 1.6171 - accuracy: 0.4671 - val_loss: 1.5571 - val_accuracy: 0.4732 - lr: 0.0010
# Epoch 18/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6240 - accuracy: 0.4657
# Epoch 18: val_loss did not improve from 1.49249
# 1462/1462 [==============================] - 558s 382ms/step - loss: 1.6240 - accuracy: 0.4657 - val_loss: 1.5123 - val_accuracy: 0.4838 - lr: 0.0010
# Epoch 19/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6218 - accuracy: 0.4669
# Epoch 19: val_loss did not improve from 1.49249
# 1462/1462 [==============================] - 562s 385ms/step - loss: 1.6218 - accuracy: 0.4669 - val_loss: 1.5210 - val_accuracy: 0.4864 - lr: 0.0010
# Epoch 20/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6220 - accuracy: 0.4649
# Epoch 20: val_loss did not improve from 1.49249
# 1462/1462 [==============================] - 570s 390ms/step - loss: 1.6220 - accuracy: 0.4649 - val_loss: 1.4975 - val_accuracy: 0.5020 - lr: 0.0010
# Epoch 21/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.6149 - accuracy: 0.4702
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 21: val_loss did not improve from 1.49249
# 1462/1462 [==============================] - 567s 387ms/step - loss: 1.6149 - accuracy: 0.4702 - val_loss: 1.5135 - val_accuracy: 0.4907 - lr: 0.0010
# Epoch 22/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.5341 - accuracy: 0.4909
# Epoch 22: val_loss improved from 1.49249 to 1.41181, saving model to best_model.keras
# 1462/1462 [==============================] - 559s 382ms/step - loss: 1.5341 - accuracy: 0.4909 - val_loss: 1.4118 - val_accuracy: 0.5077 - lr: 3.0000e-04
# Epoch 23/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4989 - accuracy: 0.4997
# Epoch 23: val_loss improved from 1.41181 to 1.37626, saving model to best_model.keras
# 1462/1462 [==============================] - 557s 381ms/step - loss: 1.4989 - accuracy: 0.4997 - val_loss: 1.3763 - val_accuracy: 0.5237 - lr: 3.0000e-04
# Epoch 24/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4902 - accuracy: 0.4989
# Epoch 24: val_loss improved from 1.37626 to 1.37106, saving model to best_model.keras
# 1462/1462 [==============================] - 558s 381ms/step - loss: 1.4902 - accuracy: 0.4989 - val_loss: 1.3711 - val_accuracy: 0.5174 - lr: 3.0000e-04
# Epoch 25/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4757 - accuracy: 0.5024
# Epoch 25: val_loss did not improve from 1.37106
# 1462/1462 [==============================] - 557s 381ms/step - loss: 1.4757 - accuracy: 0.5024 - val_loss: 1.3814 - val_accuracy: 0.5224 - lr: 3.0000e-04
# Epoch 26/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4683 - accuracy: 0.5072
# Epoch 26: val_loss improved from 1.37106 to 1.35108, saving model to best_model.keras
# 1462/1462 [==============================] - 559s 382ms/step - loss: 1.4683 - accuracy: 0.5072 - val_loss: 1.3511 - val_accuracy: 0.5341 - lr: 3.0000e-04
# Epoch 27/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4581 - accuracy: 0.5101
# Epoch 27: val_loss improved from 1.35108 to 1.33619, saving model to best_model.keras
# 1462/1462 [==============================] - 559s 383ms/step - loss: 1.4581 - accuracy: 0.5101 - val_loss: 1.3362 - val_accuracy: 0.5316 - lr: 3.0000e-04
# Epoch 28/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4506 - accuracy: 0.5150
# Epoch 28: val_loss improved from 1.33619 to 1.32786, saving model to best_model.keras
# 1462/1462 [==============================] - 558s 382ms/step - loss: 1.4506 - accuracy: 0.5150 - val_loss: 1.3279 - val_accuracy: 0.5382 - lr: 3.0000e-04
# Epoch 29/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4490 - accuracy: 0.5157
# Epoch 29: val_loss did not improve from 1.32786
# 1462/1462 [==============================] - 557s 381ms/step - loss: 1.4490 - accuracy: 0.5157 - val_loss: 1.3621 - val_accuracy: 0.5213 - lr: 3.0000e-04
# Epoch 30/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4514 - accuracy: 0.5124
# Epoch 30: val_loss improved from 1.32786 to 1.32391, saving model to best_model.keras
# 1462/1462 [==============================] - 559s 382ms/step - loss: 1.4514 - accuracy: 0.5124 - val_loss: 1.3239 - val_accuracy: 0.5354 - lr: 3.0000e-04
# Epoch 31/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4381 - accuracy: 0.5202
# Epoch 31: val_loss improved from 1.32391 to 1.30081, saving model to best_model.keras
# 1462/1462 [==============================] - 557s 381ms/step - loss: 1.4381 - accuracy: 0.5202 - val_loss: 1.3008 - val_accuracy: 0.5441 - lr: 3.0000e-04
# Epoch 32/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4386 - accuracy: 0.5209
# Epoch 32: val_loss improved from 1.30081 to 1.28881, saving model to best_model.keras
# 1462/1462 [==============================] - 556s 381ms/step - loss: 1.4386 - accuracy: 0.5209 - val_loss: 1.2888 - val_accuracy: 0.5583 - lr: 3.0000e-04
# Epoch 33/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4392 - accuracy: 0.5185
# Epoch 33: val_loss did not improve from 1.28881
# 1462/1462 [==============================] - 558s 382ms/step - loss: 1.4392 - accuracy: 0.5185 - val_loss: 1.3429 - val_accuracy: 0.5278 - lr: 3.0000e-04
# Epoch 34/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4321 - accuracy: 0.5248
# Epoch 34: val_loss did not improve from 1.28881
# 1462/1462 [==============================] - 560s 383ms/step - loss: 1.4321 - accuracy: 0.5248 - val_loss: 1.3109 - val_accuracy: 0.5436 - lr: 3.0000e-04
# Epoch 35/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4321 - accuracy: 0.5215
# Epoch 35: val_loss improved from 1.28881 to 1.28505, saving model to best_model.keras
# 1462/1462 [==============================] - 557s 381ms/step - loss: 1.4321 - accuracy: 0.5215 - val_loss: 1.2850 - val_accuracy: 0.5531 - lr: 3.0000e-04
# Epoch 36/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4292 - accuracy: 0.5257
# Epoch 36: val_loss improved from 1.28505 to 1.27181, saving model to best_model.keras
# 1462/1462 [==============================] - 560s 383ms/step - loss: 1.4292 - accuracy: 0.5257 - val_loss: 1.2718 - val_accuracy: 0.5699 - lr: 3.0000e-04
# Epoch 37/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4284 - accuracy: 0.5236
# Epoch 37: val_loss did not improve from 1.27181
# 1462/1462 [==============================] - 559s 383ms/step - loss: 1.4284 - accuracy: 0.5236 - val_loss: 1.3062 - val_accuracy: 0.5444 - lr: 3.0000e-04
# Epoch 38/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4269 - accuracy: 0.5277
# Epoch 38: val_loss improved from 1.27181 to 1.26672, saving model to best_model.keras
# 1462/1462 [==============================] - 557s 381ms/step - loss: 1.4269 - accuracy: 0.5277 - val_loss: 1.2667 - val_accuracy: 0.5667 - lr: 3.0000e-04
# Epoch 39/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4249 - accuracy: 0.5260
# Epoch 39: val_loss improved from 1.26672 to 1.26424, saving model to best_model.keras
# 1462/1462 [==============================] - 560s 383ms/step - loss: 1.4249 - accuracy: 0.5260 - val_loss: 1.2642 - val_accuracy: 0.5697 - lr: 3.0000e-04
# Epoch 40/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4210 - accuracy: 0.5271
# Epoch 40: val_loss did not improve from 1.26424
# 1462/1462 [==============================] - 560s 383ms/step - loss: 1.4210 - accuracy: 0.5271 - val_loss: 1.2895 - val_accuracy: 0.5615 - lr: 3.0000e-04
# Epoch 41/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4247 - accuracy: 0.5273
# Epoch 41: val_loss did not improve from 1.26424
# 1462/1462 [==============================] - 561s 384ms/step - loss: 1.4247 - accuracy: 0.5273 - val_loss: 1.2835 - val_accuracy: 0.5584 - lr: 3.0000e-04
# Epoch 42/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4189 - accuracy: 0.5302
# Epoch 42: val_loss improved from 1.26424 to 1.25441, saving model to best_model.keras
# 1462/1462 [==============================] - 560s 383ms/step - loss: 1.4189 - accuracy: 0.5302 - val_loss: 1.2544 - val_accuracy: 0.5624 - lr: 3.0000e-04
# Epoch 43/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4242 - accuracy: 0.5301
# Epoch 43: val_loss did not improve from 1.25441
# 1462/1462 [==============================] - 559s 382ms/step - loss: 1.4242 - accuracy: 0.5301 - val_loss: 1.2738 - val_accuracy: 0.5615 - lr: 3.0000e-04
# Epoch 44/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4162 - accuracy: 0.5322
# Epoch 44: val_loss did not improve from 1.25441
# 1462/1462 [==============================] - 559s 382ms/step - loss: 1.4162 - accuracy: 0.5322 - val_loss: 1.2555 - val_accuracy: 0.5664 - lr: 3.0000e-04
# Epoch 45/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4175 - accuracy: 0.5326
# Epoch 45: val_loss did not improve from 1.25441
# 1462/1462 [==============================] - 559s 382ms/step - loss: 1.4175 - accuracy: 0.5326 - val_loss: 1.2618 - val_accuracy: 0.5674 - lr: 3.0000e-04
# Epoch 46/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4186 - accuracy: 0.5308
# Epoch 46: val_loss did not improve from 1.25441
# 1462/1462 [==============================] - 557s 381ms/step - loss: 1.4186 - accuracy: 0.5308 - val_loss: 1.2793 - val_accuracy: 0.5541 - lr: 3.0000e-04
# Epoch 47/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.4184 - accuracy: 0.5306
# Epoch 47: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 47: val_loss did not improve from 1.25441
# 1462/1462 [==============================] - 559s 382ms/step - loss: 1.4184 - accuracy: 0.5306 - val_loss: 1.2562 - val_accuracy: 0.5670 - lr: 3.0000e-04
# Epoch 48/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3789 - accuracy: 0.5432
# Epoch 48: val_loss improved from 1.25441 to 1.22648, saving model to best_model.keras
# 1462/1462 [==============================] - 560s 383ms/step - loss: 1.3789 - accuracy: 0.5432 - val_loss: 1.2265 - val_accuracy: 0.5802 - lr: 9.0000e-05
# Epoch 49/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3608 - accuracy: 0.5509
# Epoch 49: val_loss did not improve from 1.22648
# 1462/1462 [==============================] - 559s 383ms/step - loss: 1.3608 - accuracy: 0.5509 - val_loss: 1.2281 - val_accuracy: 0.5747 - lr: 9.0000e-05
# Epoch 50/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3670 - accuracy: 0.5469
# Epoch 50: val_loss improved from 1.22648 to 1.19923, saving model to best_model.keras
# 1462/1462 [==============================] - 558s 382ms/step - loss: 1.3670 - accuracy: 0.5469 - val_loss: 1.1992 - val_accuracy: 0.5940 - lr: 9.0000e-05
# Epoch 51/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3591 - accuracy: 0.5525
# Epoch 51: val_loss did not improve from 1.19923
# 1462/1462 [==============================] - 558s 382ms/step - loss: 1.3591 - accuracy: 0.5525 - val_loss: 1.2055 - val_accuracy: 0.5900 - lr: 9.0000e-05
# Epoch 52/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3531 - accuracy: 0.5505
# Epoch 52: val_loss did not improve from 1.19923
# 1462/1462 [==============================] - 656s 449ms/step - loss: 1.3531 - accuracy: 0.5505 - val_loss: 1.2106 - val_accuracy: 0.5843 - lr: 9.0000e-05
# Epoch 53/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3487 - accuracy: 0.5546
# Epoch 53: val_loss improved from 1.19923 to 1.19681, saving model to best_model.keras
# 1462/1462 [==============================] - 571s 390ms/step - loss: 1.3487 - accuracy: 0.5546 - val_loss: 1.1968 - val_accuracy: 0.5885 - lr: 9.0000e-05
# Epoch 54/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3511 - accuracy: 0.5550
# Epoch 54: val_loss did not improve from 1.19681
# 1462/1462 [==============================] - 560s 383ms/step - loss: 1.3511 - accuracy: 0.5550 - val_loss: 1.2080 - val_accuracy: 0.5853 - lr: 9.0000e-05
# Epoch 55/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3473 - accuracy: 0.5524
# Epoch 55: val_loss improved from 1.19681 to 1.18911, saving model to best_model.keras
# 1462/1462 [==============================] - 561s 384ms/step - loss: 1.3473 - accuracy: 0.5524 - val_loss: 1.1891 - val_accuracy: 0.5985 - lr: 9.0000e-05
# Epoch 56/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3486 - accuracy: 0.5557
# Epoch 56: val_loss did not improve from 1.18911
# 1462/1462 [==============================] - 561s 384ms/step - loss: 1.3486 - accuracy: 0.5557 - val_loss: 1.2042 - val_accuracy: 0.5882 - lr: 9.0000e-05
# Epoch 57/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3422 - accuracy: 0.5579
# Epoch 57: val_loss did not improve from 1.18911
# 1462/1462 [==============================] - 561s 384ms/step - loss: 1.3422 - accuracy: 0.5579 - val_loss: 1.1949 - val_accuracy: 0.5882 - lr: 9.0000e-05
# Epoch 58/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3422 - accuracy: 0.5581
# Epoch 58: val_loss did not improve from 1.18911
# 1462/1462 [==============================] - 557s 381ms/step - loss: 1.3422 - accuracy: 0.5581 - val_loss: 1.1915 - val_accuracy: 0.5996 - lr: 9.0000e-05
# Epoch 59/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3492 - accuracy: 0.5545
# Epoch 59: val_loss did not improve from 1.18911
# 1462/1462 [==============================] - 565s 386ms/step - loss: 1.3492 - accuracy: 0.5545 - val_loss: 1.1948 - val_accuracy: 0.5943 - lr: 9.0000e-05
# Epoch 60/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3419 - accuracy: 0.5589
# Epoch 60: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
#
# Epoch 60: val_loss did not improve from 1.18911
# 1462/1462 [==============================] - 550s 376ms/step - loss: 1.3419 - accuracy: 0.5589 - val_loss: 1.1941 - val_accuracy: 0.5939 - lr: 9.0000e-05
# Epoch 61/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3341 - accuracy: 0.5616
# Epoch 61: val_loss improved from 1.18911 to 1.17943, saving model to best_model.keras
# 1462/1462 [==============================] - 580s 397ms/step - loss: 1.3341 - accuracy: 0.5616 - val_loss: 1.1794 - val_accuracy: 0.5980 - lr: 2.7000e-05
# Epoch 62/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3318 - accuracy: 0.5609
# Epoch 62: val_loss improved from 1.17943 to 1.16635, saving model to best_model.keras
# 1462/1462 [==============================] - 584s 400ms/step - loss: 1.3318 - accuracy: 0.5609 - val_loss: 1.1664 - val_accuracy: 0.6057 - lr: 2.7000e-05
# Epoch 63/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3245 - accuracy: 0.5648
# Epoch 63: val_loss did not improve from 1.16635
# 1462/1462 [==============================] - 700s 479ms/step - loss: 1.3245 - accuracy: 0.5648 - val_loss: 1.1784 - val_accuracy: 0.5965 - lr: 2.7000e-05
# Epoch 64/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3254 - accuracy: 0.5636
# Epoch 64: val_loss did not improve from 1.16635
# 1462/1462 [==============================] - 660s 451ms/step - loss: 1.3254 - accuracy: 0.5636 - val_loss: 1.1850 - val_accuracy: 0.5942 - lr: 2.7000e-05
# Epoch 65/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3239 - accuracy: 0.5637
# Epoch 65: val_loss did not improve from 1.16635
# 1462/1462 [==============================] - 651s 445ms/step - loss: 1.3239 - accuracy: 0.5637 - val_loss: 1.1769 - val_accuracy: 0.5972 - lr: 2.7000e-05
# Epoch 66/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3222 - accuracy: 0.5651
# Epoch 66: val_loss did not improve from 1.16635
# 1462/1462 [==============================] - 647s 443ms/step - loss: 1.3222 - accuracy: 0.5651 - val_loss: 1.1827 - val_accuracy: 0.5947 - lr: 2.7000e-05
# Epoch 67/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3236 - accuracy: 0.5655
# Epoch 67: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
#
# Epoch 67: val_loss did not improve from 1.16635
# 1462/1462 [==============================] - 579s 396ms/step - loss: 1.3236 - accuracy: 0.5655 - val_loss: 1.1712 - val_accuracy: 0.6023 - lr: 2.7000e-05
# Epoch 68/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3134 - accuracy: 0.5684
# Epoch 68: val_loss did not improve from 1.16635
# 1462/1462 [==============================] - 610s 417ms/step - loss: 1.3134 - accuracy: 0.5684 - val_loss: 1.1747 - val_accuracy: 0.5996 - lr: 8.1000e-06
# Epoch 69/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3136 - accuracy: 0.5704
# Epoch 69: val_loss did not improve from 1.16635
# 1462/1462 [==============================] - 552s 378ms/step - loss: 1.3136 - accuracy: 0.5704 - val_loss: 1.1716 - val_accuracy: 0.6020 - lr: 8.1000e-06
# Epoch 70/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3170 - accuracy: 0.5675
# Epoch 70: val_loss did not improve from 1.16635
# 1462/1462 [==============================] - 576s 394ms/step - loss: 1.3170 - accuracy: 0.5675 - val_loss: 1.1762 - val_accuracy: 0.5991 - lr: 8.1000e-06
# Epoch 71/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3141 - accuracy: 0.5693
# Epoch 71: val_loss did not improve from 1.16635
# 1462/1462 [==============================] - 579s 396ms/step - loss: 1.3141 - accuracy: 0.5693 - val_loss: 1.1718 - val_accuracy: 0.6012 - lr: 8.1000e-06
# Epoch 72/100
# 1462/1462 [==============================] - ETA: 0s - loss: 1.3192 - accuracy: 0.5670Restoring model weights from the end of the best epoch: 62.
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
#
# Epoch 72: val_loss did not improve from 1.16635
# 1462/1462 [==============================] - 563s 385ms/step - loss: 1.3192 - accuracy: 0.5670 - val_loss: 1.1744 - val_accuracy: 0.5988 - lr: 8.1000e-06
# Epoch 72: early stopping

# %% [markdown]
# # ROC AUC Score

# %%
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import label_binarize

y_true = test_gen.classes
y_score = model.predict(test_gen, verbose=1)

y_true_binarized = label_binarize(y_true, classes=list(range(len(test_gen.class_indices))))

roc_auc = roc_auc_score(y_true_binarized, y_score, average='macro', multi_class='ovr')
print(f"ROC AUC Score (Macro Average): {roc_auc:.4f}")
# Out:
# 545/545 [==============================] - 170s 310ms/step
# ROC AUC Score (Macro Average): 0.9523

# %% [markdown]
# # Precesion-Recall-F1score

# %%
from sklearn.metrics import classification_report
import numpy as np

y_pred = model.predict(test_gen)
y_true = test_gen.classes
y_pred_classes = np.argmax(y_pred, axis=1)

print(classification_report(y_true, y_pred_classes, target_names=test_gen.class_indices.keys()))
# Out:
# 545/545 [==============================] - 180s 330ms/step
#                      precision    recall  f1-score   support
#
#           Blackhead       0.54      0.96      0.69      6909
#          Conglobata       1.00      0.11      0.20        80
#        Crystanlline       0.63      0.49      0.55       414
#              Cystic       0.71      0.30      0.42      2240
#           Flat_wart       0.88      0.23      0.37      1094
#        Folliculitis       0.90      0.27      0.42       780
#              Keloid       1.00      0.33      0.49       870
#              Milium       0.91      0.41      0.57       815
#             Papular       0.72      0.46      0.56      3529
#            Purulent       0.89      0.42      0.57       388
#               Scars       0.89      0.40      0.55        43
# Sebo-crystan-conglo       1.00      0.12      0.22        57
#           Syringoma       1.00      0.64      0.78        86
#           Whitehead       0.77      0.62      0.68       112
#
#            accuracy                           0.61     17417
#           macro avg       0.84      0.41      0.51     17417
#        weighted avg       0.69      0.61      0.57     17417

# %% [markdown]
# # test akurasi training

# %%
test_loss, test_acc = model.evaluate(test_gen)
print(f'\n Akurasi Testing: {test_acc * 100:.2f}%')
# Out:
# 545/545 [==============================] - 172s 316ms/step - loss: 1.1740 - accuracy: 0.6050
#
#  Akurasi Testing: 60.50%

# %% [markdown]
# # Plot evaluasi

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Simpan Model

# %%
model.save("model_24_may_2025.keras")
print("Model tersimpan sebagai model_24_may_2025.keras")
# Out:
# Model tersimpan sebagai model_24_may_2025.keras

# %% [markdown]
# # Inferensi

# %%
import tensorflow as tf
model = tf.keras.models.load_model("model_23_may_2025.keras")

# %%
from tensorflow.keras.preprocessing import image
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Muat model terlatih
model = tf.keras.models.load_model("model_23_may_2025.keras")

# Path gambar uji
img_path = "papula.jpg"
img = image.load_img(img_path, target_size=image_size)

# Pra-pemrosesan
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0  # Normalisasi sesuai training

# Prediksi
predictions = model.predict(img_array)
predicted_class = np.argmax(predictions[0])
class_labels = list(train_gen.class_indices.keys())
confidence = predictions[0][predicted_class]

# Tampilkan hasil
plt.imshow(img)
plt.title(f"Prediksi: {class_labels[predicted_class]} ({confidence:.2f})")
plt.axis("off")
plt.show()
# Out:
# 1/1 [==============================] - 1s 939ms/step
